# %%
import os
from dotenv import load_dotenv

load_dotenv()

api_key = os.environ.get("OPENAI_API_KEY")

if not api_key:
    raise ValueError("API key not found!")

# %%
from agents import Agent, Runner, function_tool

agent = Agent(
    name = 'Basic Agent',
    instructions = 'You are an expert AWS assistant who will give provide commands to create all types of services in AWS account',
    model = 'gpt-5-nano-2025-08-07'
)

result = await Runner.run(agent, 'give command to create EC2')
result.final_output
# Out:
# 'Here is a ready-to-run AWS CLI command to launch an EC2 instance. Replace the placeholders with your values.\n\nQuick/Minimal (placeholders):\naws ec2 run-instances \\\n  --image-id ami-REPLACE_WITH_AMI_ID \\\n  --count 1 \\\n  --instance-type t3.micro \\\n  --key-name MyKeyPair \\\n  --security-group-ids sg-REPLACE_WITH_SG_ID \\\n  --subnet-id subnet-REPLACE_WITH_SUBNET_ID \\\n  --associate-public-ip-address \\\n  --tag-specifications \'ResourceType=instance,Tags=[{Key=Name,Value=MyEC2Instance}]\'\n\nNotes:\n- Replace AMI ID with a region-appropriate AMI. Use an Amazon Linux 2 or Ubuntu image that exists in your region.\n- Ensure you have created a key pair (MyKeyPair) in the same region.\n- Security group (sg-...) should allow SSH (port 22) if you plan to SSH into the instance.\n- Subnet (subnet-...) should exist in your VPC in the target region.\n\nOptional: auto-select the latest Amazon Linux 2 AMI in a region (two-step approach)\n1) Get the latest Amazon Linux 2 AMI ID (in your region):\nIMAGE_ID=$(aws ec2 describe-images --owners amazon \\\n  --filters "Name=name,Values=amzn2-ami-hvm-2.0-*-x86_64-ebs" "Name=state,Value=available" \\\n  --query \'Images | sort_by(@, &CreationDate) | [-1].ImageId\' \\\n  --output text --region us-east-1)\n\n2) Launch using that image ID:\naws ec2 run-instances \\\n  --image-id "$IMAGE_ID" \\\n  --count 1 \\\n  --instance-type t3.micro \\\n  --key-name MyKeyPair \\\n  --security-group-ids sg-REPLACE_WITH_SG_ID \\\n  --subnet-id subnet-REPLACE_WITH_SUBNET_ID \\\n  --associate-public-ip-address \\\n  --tag-specifications \'ResourceType=instance,Tags=[{Key=Name,Value=MyEC2Instance}]\'\n\nPrerequisites you’ll need set up first:\n- AWS CLI installed and configured with appropriate credentials and default region (or use --region in commands).\n- A key pair created in the target region (MyKeyPair).\n- A security group that allows SSH (port 22) if you want SSH access.\n- A subnet in your VPC for the instance (unless you’re using an alternative network interface setup).\n\nIf you share your region, instance type, and whether you want a specific OS image, I can tailor the exact command with the correct AMI ID.'
